# %%
def gradient(x):
    return 2 * (x + 3)
def function(x):
    return (x + 3) ** 2

# %%
x = 1
learning_rate = 0.1
num_iterations = 100

for i in range(num_iterations):
    x = x - learning_rate * gradient(x)

local_minimum = function(x)
print(f'Local minimum at x = {x}, y = {local_minimum}')
# Out:
# Local minimum at x = -2.9999999991851856, y = 6.639225686074091e-19
